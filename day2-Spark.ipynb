# %%
from pyspark.sql import SparkSession

# Start Spark session
spark = SparkSession.builder \
    .appName("Day2-Spark") \
    .master("local[*]") \
    .getOrCreate()

spark.sparkContext.setLogLevel("INFO")
print("Spark UI URL:", spark.sparkContext.uiWebUrl)
# Out:
# Spark UI URL: http://DESKTOP-KRET721.mshome.net:4040

# %%
csv_path = r"E:\pyspark-training\data\small\online_retail.csv"

df = spark.read.option("header", "true").option("inferSchema", "true").csv(csv_path)

# %%
df.show()
df.explain(True)
# Out:
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|        InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|2010-12-01 08:26:00|     2.55|   17850.0|United Kingdom|
# |   536365|    71053| WHITE METAL LANTERN|       6|2010-12-01 08:26:00|     3.39|   17850.0|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|2010-12-01 08:26:00|     2.75|   17850.0|United Kingdom|
# |   536365|   84029G|KNITTED UNION FLA...|       6|2010-12-01 08:26:00|     3.39|   17850.0|United Kingdom|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|2010-12-01 08:26:00|     3.39|   17850.0|United Kingdom|
# |   536365|    22752|SET 7 BABUSHKA NE...|       2|2010-12-01 08:26:00|     7.65|   17850.0|United Kingdom|
# |   536365|    21730|GLASS STAR FROSTE...|       6|2010-12-01 08:26:00|     4.25|   17850.0|United Kingdom|
# |   536366|    22633|HAND WARMER UNION...|       6|2010-12-01 08:28:00|     1.85|   17850.0|United Kingdom|
# |   536366|    22632|HAND WARMER RED P...|       6|2010-12-01 08:28:00|     1.85|   17850.0|United Kingdom|
# |   536367|    84879|ASSORTED COLOUR B...|      32|2010-12-01 08:34:00|     1.69|   13047.0|United Kingdom|
# |   536367|    22745|POPPY'S PLAYHOUSE...|       6|2010-12-01 08:34:00|      2.1|   13047.0|United Kingdom|
# |   536367|    22748|POPPY'S PLAYHOUSE...|       6|2010-12-01 08:34:00|      2.1|   13047.0|United Kingdom|
# |   536367|    22749|FELTCRAFT PRINCES...|       8|2010-12-01 08:34:00|     3.75|   13047.0|United Kingdom|
# |   536367|    22310|IVORY KNITTED MUG...|       6|2010-12-01 08:34:00|     1.65|   13047.0|United Kingdom|
# |   536367|    84969|BOX OF 6 ASSORTED...|       6|2010-12-01 08:34:00|     4.25|   13047.0|United Kingdom|
# |   536367|    22623|BOX OF VINTAGE JI...|       3|2010-12-01 08:34:00|     4.95|   13047.0|United Kingdom|
# |   536367|    22622|BOX OF VINTAGE AL...|       2|2010-12-01 08:34:00|     9.95|   13047.0|United Kingdom|
# |   536367|    21754|HOME BUILDING BLO...|       3|2010-12-01 08:34:00|     5.95|   13047.0|United Kingdom|
# |   536367|    21755|LOVE BUILDING BLO...|       3|2010-12-01 08:34:00|     5.95|   13047.0|United Kingdom|
# |   536367|    21777|RECIPE BOX WITH M...|       4|2010-12-01 08:34:00|     7.95|   13047.0|United Kingdom|
# +---------+---------+--------------------+--------+-------------------+---------+----------+--------------+
# only showing top 20 rows
#
# == Parsed Logical Plan ==
# Relation [InvoiceNo#92,StockCode#93,Description#94,Quantity#95,InvoiceDate#96,UnitPrice#97,CustomerID#98,Country#99] csv
#
# == Analyzed Logical Plan ==
# InvoiceNo: string, StockCode: string, Description: string, Quantity: int, InvoiceDate: timestamp, UnitPrice: double, CustomerID: double, Country: string
# Relation [InvoiceNo#92,StockCode#93,Description#94,Quantity#95,InvoiceDate#96,UnitPrice#97,CustomerID#98,Country#99] csv
#
# == Optimized Logical Plan ==
# Relation [InvoiceNo#92,StockCode#93,Description#94,Quantity#95,InvoiceDate#96,UnitPrice#97,CustomerID#98,Country#99] csv
#
# == Physical Plan ==
# FileScan csv [InvoiceNo#92,StockCode#93,Description#94,Quantity#95,InvoiceDate#96,UnitPrice#97,CustomerID#98,Country#99] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/E:/pyspark-training/data/small/online_retail.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<InvoiceNo:string,StockCode:string,Description:string,Quantity:int,InvoiceDate:timestamp,Un...

# %%
df.show(500000)

# %%
spark.stop()
